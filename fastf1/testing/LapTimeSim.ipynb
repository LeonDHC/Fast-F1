# %%
Number_of_Laps = 50
Track_Length = 4.5 #km
Track_Temp = 25 #C
Track_Condition = 1.0 # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace_Soft = 94.5
BasePace_Medium = 95.5
TireDegradation = 0.1

Sensetivity_Weight = 0.3 # s/kg
Fuel_Start = 45 #kg
Fuel_Burn = 0.5 #kg/lap

StopTime_Delta = 22 #s
StopTime_Delta_SC = 12 #s
StopTime_Delta_VSC = 16 #s
SC_Active = False
VSC_Active = False
Stop_ThisLap = False
Stop_Remaining = True

DirtyAir = False
DirtyAir_Loss = 0.1 #s

CumulativeLapTime = 0.0  # s

for i in range(1, Number_of_Laps + 1):
    Fuel_Remaining = Fuel_Start - (i * Fuel_Burn)
    Fuel_Burnt = Fuel_Start - Fuel_Remaining
    if Stop_ThisLap == True:
        Stop_ThisLap = False
    if Stop_Remaining == True:
        Stop_ThisLap = True
        Stop_Remaining = False
    if SC_Active == True:
        StopTime_Delta = StopTime_Delta_SC
    elif VSC_Active == True:
        StopTime_Delta = StopTime_Delta_VSC
    else:
        StopTime_Delta = StopTime_Delta
    CurrentLapTime = BasePace_Soft + i * (1 + TireDegradation) - (Sensetivity_Weight * Fuel_Burnt) + StopTime_Delta*Stop_ThisLap
    print(f"Lap {i}: {CurrentLapTime:.2f} seconds - Fuel Remaining: {Fuel_Remaining:.2f} kg - Stop: {Stop_ThisLap}")
    CumulativeLapTime = CumulativeLapTime + CurrentLapTime
print(f"Total Time: {CumulativeLapTime:.2f} seconds")
# Out:
# Lap 1: 117.45 seconds - Fuel Remaining: 44.50 kg - Stop: True
# Lap 2: 96.40 seconds - Fuel Remaining: 44.00 kg - Stop: False
# Lap 3: 97.35 seconds - Fuel Remaining: 43.50 kg - Stop: False
# Lap 4: 98.30 seconds - Fuel Remaining: 43.00 kg - Stop: False
# Lap 5: 99.25 seconds - Fuel Remaining: 42.50 kg - Stop: False
# Lap 6: 100.20 seconds - Fuel Remaining: 42.00 kg - Stop: False
# Lap 7: 101.15 seconds - Fuel Remaining: 41.50 kg - Stop: False
# Lap 8: 102.10 seconds - Fuel Remaining: 41.00 kg - Stop: False
# Lap 9: 103.05 seconds - Fuel Remaining: 40.50 kg - Stop: False
# Lap 10: 104.00 seconds - Fuel Remaining: 40.00 kg - Stop: False
# Lap 11: 104.95 seconds - Fuel Remaining: 39.50 kg - Stop: False
# Lap 12: 105.90 seconds - Fuel Remaining: 39.00 kg - Stop: False
# Lap 13: 106.85 seconds - Fuel Remaining: 38.50 kg - Stop: False
# Lap 14: 107.80 seconds - Fuel Remaining: 38.00 kg - Stop: False
# Lap 15: 108.75 seconds - Fuel Remaining: 37.50 kg - Stop: False
# ...

# %%
Number_of_Laps = 50
Track_Length = 4.5  # km
Track_Temp = 25  # C
Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace_Soft = 94.5
BasePace_Medium = 95.5
TireDegradation = 0.1

Sensetivity_Weight = 0.3  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s
StopTime_Delta_SC = 12  # s
StopTime_Delta_VSC = 16  # s
SC_Active = False
VSC_Active = False
Stop_ThisLap = False
Stop_Remaining = True

DirtyAir = False
DirtyAir_Loss = 0.1  # s

CurrentLapTime = BasePace_Soft
CumulativeLapTime = 0.0  # s

for i in range(1, Number_of_Laps + 1):
    Fuel_Remaining = Fuel_Start - (i * Fuel_Burn)
    Fuel_Burnt = Fuel_Start - Fuel_Remaining

    # Adjust StopTime_Delta based on SC or VSC
    if SC_Active:
        StopTime_Delta = StopTime_Delta_SC
    elif VSC_Active:
        StopTime_Delta = StopTime_Delta_VSC
    else:
        StopTime_Delta = 22  # Default stop time delta
    
  # Check if the current lap time exceeds 107% of the second lap pace
    if CurrentLapTime >= 118 and Stop_Remaining:
        Stop_ThisLap = True
        Stop_Remaining = False
    else:
        Stop_ThisLap = False

    # Calculate the current lap time
    CurrentLapTime = BasePace_Soft + i * (1 + TireDegradation) - (Sensetivity_Weight * Fuel_Burnt) + StopTime_Delta * Stop_ThisLap  

    print(f"Lap {i}: {CurrentLapTime:.2f} seconds - Fuel Remaining: {Fuel_Remaining:.2f} kg - Stop: {Stop_ThisLap}")
    CumulativeLapTime += CurrentLapTime

print(f"Total Time: {CumulativeLapTime:.2f} seconds")
# Out:
# Lap 1: 95.45 seconds - Fuel Remaining: 44.50 kg - Stop: False
# Lap 2: 96.40 seconds - Fuel Remaining: 44.00 kg - Stop: False
# Lap 3: 97.35 seconds - Fuel Remaining: 43.50 kg - Stop: False
# Lap 4: 98.30 seconds - Fuel Remaining: 43.00 kg - Stop: False
# Lap 5: 99.25 seconds - Fuel Remaining: 42.50 kg - Stop: False
# Lap 6: 100.20 seconds - Fuel Remaining: 42.00 kg - Stop: False
# Lap 7: 101.15 seconds - Fuel Remaining: 41.50 kg - Stop: False
# Lap 8: 102.10 seconds - Fuel Remaining: 41.00 kg - Stop: False
# Lap 9: 103.05 seconds - Fuel Remaining: 40.50 kg - Stop: False
# Lap 10: 104.00 seconds - Fuel Remaining: 40.00 kg - Stop: False
# Lap 11: 104.95 seconds - Fuel Remaining: 39.50 kg - Stop: False
# Lap 12: 105.90 seconds - Fuel Remaining: 39.00 kg - Stop: False
# Lap 13: 106.85 seconds - Fuel Remaining: 38.50 kg - Stop: False
# Lap 14: 107.80 seconds - Fuel Remaining: 38.00 kg - Stop: False
# Lap 15: 108.75 seconds - Fuel Remaining: 37.50 kg - Stop: False
# ...

# %%
Number_of_Laps = 50
Track_Length = 4.5  # km
Track_Temp = 25  # C
Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace_Soft = 94.5
BasePace_Medium = 95.5
BasePace_Hard = 96.5
TireDegradation = 0.1
StartTire = "Medium"
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 0.3  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s
StopTime_Delta_SC = 12  # s
StopTime_Delta_VSC = 16  # s
SC_Active = False
VSC_Active = False
Stop_ThisLap = False
Stop_Remaining = True

DirtyAir = False
DirtyAir_Loss = 0.1  # s

CurrentLapTime = BasePace_Soft
CumulativeLapTime = 0.0  # s

for i in range(1, Number_of_Laps + 1):
    Fuel_Remaining = Fuel_Start - (i * Fuel_Burn)
    Fuel_Burnt = Fuel_Start - Fuel_Remaining

    # Adjust StopTime_Delta based on SC or VSC
    if SC_Active:
        StopTime_Delta = StopTime_Delta_SC
    elif VSC_Active:
        StopTime_Delta = StopTime_Delta_VSC
    else:
        StopTime_Delta = 22  # Default stop time delta

    # Check if the current lap time exceeds 118 seconds
    if CurrentLapTime >= BasePace_Soft * 1.07 and Stop_Remaining:
        Stop_ThisLap = True
        Stop_Remaining = False
    else:
        Stop_ThisLap = False

    # Calculate the current lap time
    CurrentLapTime = BasePace_Soft + i * (1 + TireDegradation) - (Sensetivity_Weight * Fuel_Burnt) + StopTime_Delta * Stop_ThisLap

    print(f"Lap {i}: {CurrentLapTime:.2f} seconds - Fuel Remaining: {Fuel_Remaining:.2f} kg - Stop: {Stop_ThisLap}")
    CumulativeLapTime += CurrentLapTime

print(f"Total Time: {CumulativeLapTime:.2f} seconds")
# Out:
# Lap 1: 95.45 seconds - Fuel Remaining: 44.50 kg - Stop: False
# Lap 2: 96.40 seconds - Fuel Remaining: 44.00 kg - Stop: False
# Lap 3: 97.35 seconds - Fuel Remaining: 43.50 kg - Stop: False
# Lap 4: 98.30 seconds - Fuel Remaining: 43.00 kg - Stop: False
# Lap 5: 99.25 seconds - Fuel Remaining: 42.50 kg - Stop: False
# Lap 6: 100.20 seconds - Fuel Remaining: 42.00 kg - Stop: False
# Lap 7: 101.15 seconds - Fuel Remaining: 41.50 kg - Stop: False
# Lap 8: 124.10 seconds - Fuel Remaining: 41.00 kg - Stop: True
# Lap 9: 103.05 seconds - Fuel Remaining: 40.50 kg - Stop: False
# Lap 10: 104.00 seconds - Fuel Remaining: 40.00 kg - Stop: False
# Lap 11: 104.95 seconds - Fuel Remaining: 39.50 kg - Stop: False
# Lap 12: 105.90 seconds - Fuel Remaining: 39.00 kg - Stop: False
# Lap 13: 106.85 seconds - Fuel Remaining: 38.50 kg - Stop: False
# Lap 14: 107.80 seconds - Fuel Remaining: 38.00 kg - Stop: False
# Lap 15: 108.75 seconds - Fuel Remaining: 37.50 kg - Stop: False
# ...

# %%
Number_of_Laps = 50
Track_Length = 4.5  # km
Track_Temp = 25  # C
Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 96.5}  # Base pace for each tire compound
TireDegradation = 0.1
StartTire = "Medium"
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 0.3  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s
StopTime_Delta_SC = 12  # s
StopTime_Delta_VSC = 16  # s
SC_Active = False
VSC_Active = False
Stop_ThisLap = False
Stop_Remaining = True

DirtyAir = False
DirtyAir_Loss = 0.1  # s

CurrentTire = StartTire  # Start with the initial tire compound
UsedTires = [CurrentTire]  # Track the tires used during the race
CurrentLapTime = BasePace[CurrentTire]
CumulativeLapTime = 0.0  # s

for i in range(1, Number_of_Laps + 1):
    Fuel_Remaining = Fuel_Start - (i * Fuel_Burn)
    Fuel_Burnt = Fuel_Start - Fuel_Remaining

    # Adjust StopTime_Delta based on SC or VSC
    if SC_Active:
        StopTime_Delta = StopTime_Delta_SC
    elif VSC_Active:
        StopTime_Delta = StopTime_Delta_VSC
    else:
        StopTime_Delta = 22  # Default stop time delta

    # Check if the current lap time exceeds 107% of the base pace for the current tire
    if CurrentLapTime >= BasePace[CurrentTire] * 1.07 and Stop_Remaining:
        Stop_ThisLap = True
        Stop_Remaining = False

        # Switch to a different tire compound after the stop
        for tire in Tires:
            if tire not in UsedTires:  # Use a tire that hasn't been used yet
                CurrentTire = tire
                UsedTires.append(tire)
                break
    else:
        Stop_ThisLap = False

    # Calculate the current lap time
    CurrentLapTime = BasePace[CurrentTire] + i * (1 + TireDegradation) - (Sensetivity_Weight * Fuel_Burnt) + StopTime_Delta * Stop_ThisLap

    print(f"Lap {i}: {CurrentLapTime:.2f} seconds - Fuel Remaining: {Fuel_Remaining:.2f} kg - Stop: {Stop_ThisLap} - Tire: {CurrentTire}")
    CumulativeLapTime += CurrentLapTime

print(f"Total Time: {CumulativeLapTime:.2f} seconds")
# Out:
# Lap 1: 96.45 seconds - Fuel Remaining: 44.50 kg - Stop: False - Tire: Medium
# Lap 2: 97.40 seconds - Fuel Remaining: 44.00 kg - Stop: False - Tire: Medium
# Lap 3: 98.35 seconds - Fuel Remaining: 43.50 kg - Stop: False - Tire: Medium
# Lap 4: 99.30 seconds - Fuel Remaining: 43.00 kg - Stop: False - Tire: Medium
# Lap 5: 100.25 seconds - Fuel Remaining: 42.50 kg - Stop: False - Tire: Medium
# Lap 6: 101.20 seconds - Fuel Remaining: 42.00 kg - Stop: False - Tire: Medium
# Lap 7: 102.15 seconds - Fuel Remaining: 41.50 kg - Stop: False - Tire: Medium
# Lap 8: 103.10 seconds - Fuel Remaining: 41.00 kg - Stop: False - Tire: Medium
# Lap 9: 125.05 seconds - Fuel Remaining: 40.50 kg - Stop: True - Tire: Soft
# Lap 10: 104.00 seconds - Fuel Remaining: 40.00 kg - Stop: False - Tire: Soft
# Lap 11: 104.95 seconds - Fuel Remaining: 39.50 kg - Stop: False - Tire: Soft
# Lap 12: 105.90 seconds - Fuel Remaining: 39.00 kg - Stop: False - Tire: Soft
# ...

# %%
from itertools import permutations

Number_of_Laps = 50
Track_Length = 4.5  # km
Track_Temp = 25  # C
Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 96.5}  # Base pace for each tire compound
TireDegradation = {"Soft": 0.15, "Medium": 0.1, "Hard": 0.05}  # Degradation per lap for each tire
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 0.3  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s
StopTime_Delta_SC = 12  # s
StopTime_Delta_VSC = 16  # s
SC_Active = False
VSC_Active = False

DirtyAir = False
DirtyAir_Loss = 0.1  # s

# Function to simulate a race with a given tire strategy
def simulate_race(strategy):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1
    CurrentTire = "" # Start with the first tire in the strategy
    LastTire = ""
    Stop_Remaining = True

    for tire, stint_length in strategy:
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps

               # Adjust StopTime_Delta based on SC or VSC
            if SC_Active:
                StopTime_Delta = StopTime_Delta_SC
            elif VSC_Active:
                StopTime_Delta = StopTime_Delta_VSC
            else:
                StopTime_Delta = 22  # Default stop time delta

              # Check if the current lap time exceeds 118 seconds
            if CurrentTire == LastTire:
                Stop_ThisLap = False
            else:
                Stop_ThisLap = True
                Stop_Remaining = False

            Fuel_Burnt = Fuel_Start - Fuel_Remaining
            CurrentLapTime = (
                BasePace[tire]
                + lap * TireDegradation[tire]
                - (Sensetivity_Weight * Fuel_Burnt) 
                + StopTime_Delta * Stop_ThisLap
            )
            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn
            CurrentLap += 1
            CurrentTire = tire

        # Add pit stop time if there are more stints remaining
        if CurrentLap <= Number_of_Laps:
            CumulativeLapTime += StopTime_Delta

    return CumulativeLapTime

# Generate all possible strategies (permutations of tires with stint lengths)
strategies = []
for perm in permutations(Tires, 2):  # Use exactly two different tires
    stint1 = Number_of_Laps // 2
    stint2 = Number_of_Laps - stint1
    strategies.append([(perm[0], stint1), (perm[1], stint2)])

# Simulate all strategies and find the fastest one
best_time = float("inf")
best_strategy = None

for strategy in strategies:
    total_time = simulate_race(strategy)
    if total_time < best_time:
        best_time = total_time
        best_strategy = strategy

# Output the best strategy and its total time
print(f"Best Strategy: {best_strategy}")
print(f"Total Time: {best_time:.2f} seconds")
# Out:
# Best Strategy: [('Soft', 25), ('Medium', 25)]
# Total Time: 5741.25 seconds

# %%
from itertools import permutations, product

Number_of_Laps = 50
Track_Length = 4.5  # km
Track_Temp = 25  # C
Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 96.5}  # Base pace for each tire compound
TireDegradation = {"Soft": 0.15, "Medium": 0.1, "Hard": 0.05}  # Degradation per lap for each tire
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 0.3  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s
StopTime_Delta_SC = 12  # s
StopTime_Delta_VSC = 16  # s
SC_Active = False
VSC_Active = False

DirtyAir = False
DirtyAir_Loss = 0.1  # s

# Function to simulate a race with a given tire strategy
def simulate_race(strategy):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1

    for tire, stint_length in strategy:
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps

            Fuel_Burnt = Fuel_Start - Fuel_Remaining
            CurrentLapTime = (
                BasePace[tire]
                + lap * TireDegradation[tire]
                - (Sensetivity_Weight * Fuel_Burnt)
            )
            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn

            CurrentLap += 1

        # Add pit stop time if there are more stints remaining
        if CurrentLap <= Number_of_Laps:
            CumulativeLapTime += StopTime_Delta
            print(
                f"Pit Stop: +{StopTime_Delta} seconds - Switching to next tire"
            )

    return CumulativeLapTime

# Generate all possible strategies (combinations of tires and stint lengths)
strategies = []
for num_stints in range(2, 4):  # Allow 2 or 3 stints
    for perm in permutations(Tires, num_stints):  # Use different tires for each stint
        stint_lengths = [
            Number_of_Laps // num_stints + (1 if x < Number_of_Laps % num_stints else 0)
            for x in range(num_stints)
        ]
        strategies.append(list(zip(perm, stint_lengths)))

# Simulate all strategies and find the fastest one
best_time = float("inf")
best_strategy = None

for strategy in strategies:
    print(f"\nSimulating strategy: {strategy}")
    total_time = simulate_race(strategy)
    print(f"Total Time for strategy {strategy}: {total_time:.2f} seconds\n")
    if total_time < best_time:
        best_time = total_time
        best_strategy = strategy

# Output the best strategy and its total time
print(f"Best Strategy: {best_strategy}")
print(f"Total Time: {best_time:.2f} seconds")
# Out:
# Simulating strategy: [('Soft', 25), ('Medium', 25)]
# Pit Stop: +22 seconds - Switching to next tire
# Total Time for strategy [('Soft', 25), ('Medium', 25)]: 4663.25 seconds
#
#
# Simulating strategy: [('Soft', 25), ('Hard', 25)]
# Pit Stop: +22 seconds - Switching to next tire
# Total Time for strategy [('Soft', 25), ('Hard', 25)]: 4673.25 seconds
#
#
# Simulating strategy: [('Medium', 25), ('Soft', 25)]
# Pit Stop: +22 seconds - Switching to next tire
# Total Time for strategy [('Medium', 25), ('Soft', 25)]: 4663.25 seconds
#
#
# Simulating strategy: [('Medium', 25), ('Hard', 25)]
# Pit Stop: +22 seconds - Switching to next tire
# Total Time for strategy [('Medium', 25), ('Hard', 25)]: 4683.25 seconds
#
#
# Simulating strategy: [('Hard', 25), ('Soft', 25)]
# Pit Stop: +22 seconds - Switching to next tire
# Total Time for strategy [('Hard', 25), ('Soft', 25)]: 4673.25 seconds
#
#
# Simulating strategy: [('Hard', 25), ('Medium', 25)]
# Pit Stop: +22 seconds - Switching to next tire
# ...

# %%
from itertools import permutations, product

Number_of_Laps = 50
Track_Length = 4.5  # km
Track_Temp = 25  # C
Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 96.5}  # Base pace for each tire compound
TireDegradation = {"Soft": 0.15, "Medium": 0.1, "Hard": 0.05}  # Degradation per lap for each tire
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 0.3  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s
StopTime_Delta_SC = 12  # s
StopTime_Delta_VSC = 16  # s
SC_Active = False
VSC_Active = False

DirtyAir = False
DirtyAir_Loss = 0.1  # s

# Function to simulate a race with a given tire strategy and pit stop laps
def simulate_race(strategy, pit_laps):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1
    CurrentTire = strategy[0]  # Start with the first tire in the strategy

    for stint_index, stint_length in enumerate(pit_laps + [Number_of_Laps - sum(pit_laps)]):
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps

            Fuel_Burnt = Fuel_Start - Fuel_Remaining
            CurrentLapTime = (
                BasePace[CurrentTire]
                + lap * TireDegradation[CurrentTire]
                - (Sensetivity_Weight * Fuel_Burnt)
            )
            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn

            # Print lap data
            print(
                f"Lap {CurrentLap}: {CurrentLapTime:.2f} seconds - Fuel Remaining: {Fuel_Remaining:.2f} kg - Tire: {CurrentTire}"
            )

            CurrentLap += 1

        # Add pit stop time if there are more stints remaining
        if stint_index < len(pit_laps):
            CumulativeLapTime += StopTime_Delta
            CurrentTire = strategy[stint_index + 1]  # Switch to the next tire
            print(
                f"Pit Stop: +{StopTime_Delta} seconds - Switching to next tire: {CurrentTire}"
            )

    return CumulativeLapTime

# Generate all possible strategies (combinations of tires and pit stop laps)
strategies = []
for perm in permutations(Tires, 2):  # Use exactly two different tires
    for pit_lap in range(1, Number_of_Laps):  # Simulate all possible pit stop laps
        strategies.append((perm, [pit_lap]))

# Simulate all strategies and find the fastest one
best_time = float("inf")
best_strategy = None

for strategy, pit_laps in strategies:
    print(f"\nSimulating strategy: {strategy} with pit stops at laps {pit_laps}")
    total_time = simulate_race(strategy, pit_laps)
    print(f"Total Time for strategy {strategy} with pit stops at laps {pit_laps}: {total_time:.2f} seconds\n")
    if total_time < best_time:
        best_time = total_time
        best_strategy = (strategy, pit_laps)

# Output the best strategy and its total time
print(f"Best Strategy: {best_strategy[0]} with pit stops at laps {best_strategy[1]}")
print(f"Total Time: {best_time:.2f} seconds")
# Out:
# Simulating strategy: ('Soft', 'Medium') with pit stops at laps [1]
# Lap 1: 94.50 seconds - Fuel Remaining: 44.50 kg - Tire: Soft
# Pit Stop: +22 seconds - Switching to next tire: Medium
# Lap 2: 95.35 seconds - Fuel Remaining: 44.00 kg - Tire: Medium
# Lap 3: 95.30 seconds - Fuel Remaining: 43.50 kg - Tire: Medium
# Lap 4: 95.25 seconds - Fuel Remaining: 43.00 kg - Tire: Medium
# Lap 5: 95.20 seconds - Fuel Remaining: 42.50 kg - Tire: Medium
# Lap 6: 95.15 seconds - Fuel Remaining: 42.00 kg - Tire: Medium
# Lap 7: 95.10 seconds - Fuel Remaining: 41.50 kg - Tire: Medium
# Lap 8: 95.05 seconds - Fuel Remaining: 41.00 kg - Tire: Medium
# Lap 9: 95.00 seconds - Fuel Remaining: 40.50 kg - Tire: Medium
# Lap 10: 94.95 seconds - Fuel Remaining: 40.00 kg - Tire: Medium
# Lap 11: 94.90 seconds - Fuel Remaining: 39.50 kg - Tire: Medium
# Lap 12: 94.85 seconds - Fuel Remaining: 39.00 kg - Tire: Medium
# Lap 13: 94.80 seconds - Fuel Remaining: 38.50 kg - Tire: Medium
# ...

# %%
import matplotlib.pyplot as plt
from itertools import permutations

Number_of_Laps = 50
Track_Length = 4.5  # km
Track_Temp = 25  # C
Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 96.5}  # Base pace for each tire compound
TireDegradation = {"Soft": 0.15, "Medium": 0.1, "Hard": 0.05}  # Degradation per lap for each tire
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 0.3  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s

# Function to simulate a race with a given tire strategy and pit stop laps
def simulate_race(strategy, pit_laps, plot=False):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1
    CurrentTire = strategy[0]  # Start with the first tire in the strategy
    lap_times = []  # Store lap times for plotting
    lap_numbers = []  # Store lap numbers for plotting
    tire_colors = []  # Store tire colors for plotting
    laps_on_tire = 0  # Track laps completed on the current tire

    for stint_index, stint_length in enumerate(pit_laps + [Number_of_Laps - sum(pit_laps)]):
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps

            Fuel_Burnt = Fuel_Start - Fuel_Remaining
            CurrentLapTime = (
                BasePace[CurrentTire]
                + laps_on_tire * TireDegradation[CurrentTire]  # Use cumulative laps on the tire
                - (Sensetivity_Weight * Fuel_Burnt)
            )
            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn

            # Store data for plotting
            lap_times.append(CurrentLapTime)
            lap_numbers.append(CurrentLap)
            if CurrentTire == "Soft":
                tire_colors.append("red")
            elif CurrentTire == "Medium":
                tire_colors.append("yellow")
            elif CurrentTire == "Hard":
                tire_colors.append("white")

            CurrentLap += 1
            laps_on_tire += 1  # Increment laps on the current tire

        # Add pit stop time if there are more stints remaining
        if stint_index < len(pit_laps):
            CumulativeLapTime += StopTime_Delta
            CurrentTire = strategy[stint_index + 1]  # Switch to the next tire
            laps_on_tire = 0  # Reset laps on the new tire

    if plot:
        # Plot the lap times
        plt.figure(figsize=(10, 6))
        for i in range(len(lap_numbers)):
            plt.plot(
                lap_numbers[i:i+2],  # Plot each lap as a segment
                lap_times[i:i+2],
                color=tire_colors[i],
                linewidth=2,
            )
        plt.xlabel("Lap Number")
        plt.ylabel("Lap Time (s)")
        plt.title("Lap Time Over Number of Laps (Fastest Strategy)")
        plt.grid(color="gray", linestyle="--", linewidth=0.5)
        plt.show()

    return CumulativeLapTime

# Generate all possible strategies (combinations of tires and pit stop laps)
strategies = []
for perm in permutations(Tires, 2):  # Use exactly two different tires
    for pit_lap in range(1, Number_of_Laps):  # Simulate all possible pit stop laps
        strategies.append((perm, [pit_lap]))

# Simulate all strategies and find the fastest one
best_time = float("inf")
best_strategy = None

for strategy, pit_laps in strategies:
    total_time = simulate_race(strategy, pit_laps)
    if total_time < best_time:
        best_time = total_time
        best_strategy = (strategy, pit_laps)

# Output the best strategy and its total time
print(f"Best Strategy: {best_strategy[0]} with pit stops at laps {best_strategy[1]}")
print(f"Total Time: {best_time:.2f} seconds")

# Plot the fastest strategy
simulate_race(best_strategy[0], best_strategy[1], plot=True)
# Out:
# Best Strategy: ('Soft', 'Medium') with pit stops at laps [24]
# Total Time: 4663.15 seconds
# 4663.15

# %%
def simulate_race(strategy, pit_laps, plot=False):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1
    CurrentTire = strategy[0]  # Start with the first tire in the strategy
    lap_times = []  # Store lap times for plotting
    lap_numbers = []  # Store lap numbers for plotting
    tire_colors = []  # Store tire colors for plotting
    laps_on_tire = 0  # Track laps completed on the current tire

    for stint_index, stint_length in enumerate(pit_laps + [Number_of_Laps - sum(pit_laps)]):
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps

            Fuel_Burnt = Fuel_Start - Fuel_Remaining
            CurrentLapTime = (
                BasePace[CurrentTire]
                + laps_on_tire * TireDegradation[CurrentTire]  # Use cumulative laps on the tire
                - (Sensetivity_Weight * Fuel_Burnt)
            )
            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn

            # Store data for plotting
            lap_times.append(CurrentLapTime)
            lap_numbers.append(CurrentLap)
            if CurrentTire == "Soft":
                tire_colors.append("red")
            elif CurrentTire == "Medium":
                tire_colors.append("yellow")
            elif CurrentTire == "Hard":
                tire_colors.append("white")

            CurrentLap += 1
            laps_on_tire += 1  # Increment laps on the current tire

        # Add pit stop time if there are more stints remaining
        if stint_index < len(pit_laps):
            CumulativeLapTime += StopTime_Delta
            CurrentTire = strategy[stint_index + 1]  # Switch to the next tire
            laps_on_tire = 0  # Reset laps on the new tire

    if plot:
        # Plot the lap times
        plt.figure(figsize=(10, 6))
        for i in range(len(lap_numbers)):
            plt.plot(
                lap_numbers[i:i+2],  # Plot each lap as a segment
                lap_times[i:i+2],
                color=tire_colors[i],
                linewidth=2,
            )
        plt.xlabel("Lap Number")
        plt.ylabel("Lap Time (s)")
        plt.title("Lap Time Over Number of Laps (Fastest Strategy)")
        plt.grid(color="gray", linestyle="--", linewidth=0.5)
        plt.show()

    return CumulativeLapTime

# %%
import matplotlib.pyplot as plt
from itertools import permutations

Number_of_Laps = 50
Track_Length = 4.5  # km
Track_Temp = 25  # C
Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 96.5}  # Base pace for each tire compound
TireDegradation = {"Soft": 1.5, "Medium": 1.0, "Hard": 0.5}  # Base degradation per lap for each tire
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 1.5  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s

# Function to simulate a race with a given tire strategy and pit stop laps
def simulate_race(strategy, pit_laps, plot=False):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1
    CurrentTire = strategy[0]  # Start with the first tire in the strategy
    lap_times = []  # Store lap times for plotting
    lap_numbers = []  # Store lap numbers for plotting
    tire_colors = []  # Store tire colors for plotting
    laps_on_tire = 0  # Track laps completed on the current tire

    for stint_index, stint_length in enumerate(pit_laps + [Number_of_Laps - sum(pit_laps)]):
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps

            Fuel_Burnt = Fuel_Start - Fuel_Remaining
            # Apply exponential tire degradation
            CurrentLapTime = (
                BasePace[CurrentTire]
                + TireDegradation[CurrentTire] * (1.15 ** laps_on_tire)  # Exponential degradation
                - (Sensetivity_Weight * Fuel_Burnt)
            )
            # Add pit stop time to the lap where the tire changes
            if lap == stint_length - 1 and stint_index < len(pit_laps):
                CurrentLapTime += StopTime_Delta

            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn

            # Store data for plotting
            lap_times.append(CurrentLapTime)
            lap_numbers.append(CurrentLap)
            if CurrentTire == "Soft":
                tire_colors.append("red")
            elif CurrentTire == "Medium":
                tire_colors.append("yellow")
            elif CurrentTire == "Hard":
                tire_colors.append("white")

            CurrentLap += 1
            laps_on_tire += 1  # Increment laps on the current tire

        # Switch to the next tire after the pit stop
        if stint_index < len(pit_laps):
            CurrentTire = strategy[stint_index + 1]  # Switch to the next tire
            laps_on_tire = 0  # Reset laps on the new tire

    if plot:
        # Plot the lap times with a black background
        plt.figure(figsize=(10, 6), facecolor="black")
        ax = plt.gca()
        ax.set_facecolor("black")
        for i in range(len(lap_numbers) - 1):
            plt.plot(
                lap_numbers[i:i+2],  # Plot each lap as a segment
                lap_times[i:i+2],
                color=tire_colors[i],
                linewidth=2,
            )
        plt.xlabel("Lap Number", color="white")
        plt.ylabel("Lap Time (s)", color="white")
        plt.title("Lap Time Over Number of Laps (Fastest Strategy)", color="white")
        plt.grid(color="gray", linestyle="--", linewidth=0.5)
        ax.tick_params(colors="white")  # Set tick colors to white
        plt.show()

    return CumulativeLapTime

# Generate all possible strategies (combinations of tires and pit stop laps)
strategies = []
for num_tires in range(2, 4):  # Allow up to 4 tire sets
    for perm in permutations(Tires, num_tires):  # Generate permutations of `num_tires` length
        for pit_laps in product(range(1, Number_of_Laps), repeat=num_tires - 1):  # Generate pit stop combinations
            if sum(pit_laps) < Number_of_Laps:  # Ensure total pit laps don't exceed total laps
                strategies.append((perm, list(pit_laps)))

# Simulate all strategies and find the fastest one
best_time = float("inf")
best_strategy = None

for strategy, pit_laps in strategies:
    total_time = simulate_race(strategy, pit_laps)
    if total_time < best_time:
        best_time = total_time
        best_strategy = (strategy, pit_laps)

# Output the best strategy and its total time
print(f"Best Strategy: {best_strategy[0]} with pit stops at laps {best_strategy[1]}")
print(f"Total Time: {best_time:.2f} seconds")

# Plot the fastest strategy
simulate_race(best_strategy[0], best_strategy[1], plot=True)
# Out:
# Best Strategy: ('Medium', 'Hard', 'Soft') with pit stops at laps [16, 20]
# Total Time: 4073.95 seconds
# 4073.946321444953

# %%
import matplotlib.pyplot as plt
from itertools import product
import random

Number_of_Laps = 50
# Track_Length = 4.5  # km
# Track_Temp = 25  # C
# Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 97.5}  # Base pace for each tire compound
TireDegradation = {"Soft": 1.5, "Medium": 1.0, "Hard": 0.5}  # Base degradation per lap for each tire
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 1.5  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s
StopTime_Delta_SC = 8  # s
StopTime_Delta_VSC = 16  # s
def Prob_SC():
    return random.random() < 0.0125

# Function to simulate a race with a given tire strategy and pit stop laps
def simulate_race(strategy, pit_laps, plot=False):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1
    CurrentTire = strategy[0]  # Start with the first tire in the strategy
    lap_times = []  # Store lap times for plotting
    lap_numbers = []  # Store lap numbers for plotting
    tire_colors = []  # Store tire colors for plotting
    laps_on_tire = 0  # Track laps completed on the current tire
    TimeLost = 0.0  # Initialize time lost to 0

    for stint_index, stint_length in enumerate(pit_laps + [Number_of_Laps - sum(pit_laps)]):
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps

            Fuel_Burnt = Fuel_Start - Fuel_Remaining
            # Apply exponential tire degradation
            CurrentLapTime = (
                BasePace[CurrentTire]
                + TireDegradation[CurrentTire] * (1.15 ** laps_on_tire)  # Exponential degradation
                - (Sensetivity_Weight * Fuel_Burnt)
            )
            # Add pit stop time to the lap where the tire changes
            if Prob_SC():
                TimeLost = StopTime_Delta_SC
            else:
                TimeLost =  StopTime_Delta # Set SC_Active to True if the function returns True
            if lap == stint_length - 1 and stint_index < len(pit_laps):
                CurrentLapTime += TimeLost

            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn

            # Store data for plotting
            lap_times.append(CurrentLapTime)
            lap_numbers.append(CurrentLap)
            if CurrentTire == "Soft":
                tire_colors.append("red")
            elif CurrentTire == "Medium":
                tire_colors.append("yellow")
            elif CurrentTire == "Hard":
                tire_colors.append("white")

            CurrentLap += 1
            laps_on_tire += 1  # Increment laps on the current tire

        # Switch to the next tire after the pit stop
        if stint_index < len(pit_laps):
            CurrentTire = strategy[stint_index + 1]  # Switch to the next tire
            laps_on_tire = 0  # Reset laps on the new tire

    if plot:
        # Plot the lap times with a black background
        plt.figure(figsize=(10, 6), facecolor="black")
        ax = plt.gca()
        ax.set_facecolor("black")
        for i in range(len(lap_numbers) - 1):
            plt.plot(
                lap_numbers[i:i+2],  # Plot each lap as a segment
                lap_times[i:i+2],
                color=tire_colors[i],
                linewidth=2,
            )
        plt.xlabel("Lap Number", color="white")
        plt.ylabel("Lap Time (s)", color="white")
        plt.title("Lap Time Sim (Fastest Strategy)", color="white")
        plt.grid(color="gray", linestyle="--", linewidth=0.5)
        ax.tick_params(colors="white")  # Set tick colors to white
        plt.show()

    return CumulativeLapTime

# Generate all possible strategies (combinations of tires and pit stop laps)
strategies = []
for num_tires in range(2, 4):  # Allow up to 4 tire sets
    for perm in product(Tires, repeat=num_tires):  # Allow repeated tire usage
        if len(set(perm)) < 2:  # Ensure at least two different types of tires are used
            continue  # Skip strategies with only one type of tire
        for pit_laps in product(range(1, Number_of_Laps), repeat=num_tires - 1):  # Generate pit stop combinations
            if sum(pit_laps) < Number_of_Laps:  # Ensure total pit laps don't exceed total laps
                strategies.append((perm, list(pit_laps)))

# Simulate all strategies and find the fastest one
best_time = float("inf")
best_strategy = None

for strategy, pit_laps in strategies:
    total_time = simulate_race(strategy, pit_laps)
    if total_time < best_time:
        best_time = total_time
        best_strategy = (strategy, pit_laps)

# Output the best strategy and its total time
cumulative_pit_laps = [sum(best_strategy[1][:i+1]) for i in range(len(best_strategy[1]))]  # Calculate cumulative lap numbers
print(f"Best Strategy: {best_strategy[0]} with pit stops at laps {cumulative_pit_laps}")
print(f"Total Time: {best_time:.2f} seconds")

# Plot the fastest strategy
simulate_race(best_strategy[0], best_strategy[1], plot=True)
# Out:
# Best Strategy: ('Medium', 'Hard', 'Medium') with pit stops at laps [15, 34]
# Total Time: 4071.65 seconds
# 4085.653788838127

# %%
import matplotlib.pyplot as plt
from itertools import product
import random

Number_of_Laps = 50
# Track_Length = 4.5  # km
# Track_Temp = 25  # C
# Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 97.5}  # Base pace for each tire compound
TireDegradation = {"Soft": 1.5, "Medium": 1.0, "Hard": 0.5}  # Base degradation per lap for each tire
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 1.5  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s
StopTime_Delta_SC = 8  # s
StopTime_Delta_VSC = 16  # s
def Prob_SC():
    return random.random() < 0.0125

# Function to simulate a race with a given tire strategy and pit stop laps
def simulate_race(strategy, pit_laps, plot=False):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1
    CurrentTire = strategy[0]  # Start with the first tire in the strategy
    lap_times = []  # Store lap times for plotting
    lap_numbers = []  # Store lap numbers for plotting
    tire_colors = []  # Store tire colors for plotting
    laps_on_tire = 0  # Track laps completed on the current tire
    sc_laps = []  # Track laps where Prob_SC() is True

    for stint_index, stint_length in enumerate(pit_laps + [Number_of_Laps - sum(pit_laps)]):
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps

            Fuel_Burnt = Fuel_Start - Fuel_Remaining
            # Apply exponential tire degradation
            CurrentLapTime = (
                BasePace[CurrentTire]
                + TireDegradation[CurrentTire] * (1.15 ** laps_on_tire)  # Exponential degradation
                - (Sensetivity_Weight * Fuel_Burnt)
            )
            # Check for safety car probability
            if Prob_SC():
                sc_laps.append(CurrentLap)  # Record the lap where Prob_SC() is True

            # Add pit stop time to the lap where the tire changes
            if lap == stint_length - 1 and stint_index < len(pit_laps):
                CurrentLapTime += StopTime_Delta

            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn

            # Store data for plotting
            lap_times.append(CurrentLapTime)
            lap_numbers.append(CurrentLap)
            if CurrentTire == "Soft":
                tire_colors.append("red")
            elif CurrentTire == "Medium":
                tire_colors.append("yellow")
            elif CurrentTire == "Hard":
                tire_colors.append("white")

            CurrentLap += 1
            laps_on_tire += 1  # Increment laps on the current tire

        # Switch to the next tire after the pit stop
        if stint_index < len(pit_laps):
            CurrentTire = strategy[stint_index + 1]  # Switch to the next tire
            laps_on_tire = 0  # Reset laps on the new tire

    if plot:
        # Plot the lap times with a black background
        plt.figure(figsize=(10, 6), facecolor="black")
        ax = plt.gca()
        ax.set_facecolor("black")
        for i in range(len(lap_numbers) - 1):
            plt.plot(
                lap_numbers[i:i+2],  # Plot each lap as a segment
                lap_times[i:i+2],
                color=tire_colors[i],
                linewidth=2,
            )
        # Highlight laps where Prob_SC() was True
        first_sc_label = True  # Track if it's the first SC lap for labeling
        for sc_lap in sc_laps:
            plt.axvline(
                sc_lap,
                color="blue",
                linestyle="--",
                linewidth=1,
                label="SC Active" if first_sc_label else ""  # Add label only to the first line
            )
            first_sc_label = False  # Ensure subsequent lines don't have a label
        plt.xlabel("Lap Number", color="white")
        plt.ylabel("Lap Time (s)", color="white")
        plt.title("Lap Time Sim (Fastest Strategy)", color="white")
        plt.grid(color="gray", linestyle="--", linewidth=0.5)
        ax.tick_params(colors="white")  # Set tick colors to white
        plt.legend(loc="upper left", fontsize="small", facecolor="black", edgecolor="white", labelcolor="white")
        plt.show()

    return CumulativeLapTime, sc_laps

# Generate all possible strategies (combinations of tires and pit stop laps)
strategies = []
for num_tires in range(2, 4):  # Allow up to 3 tire sets
    for perm in product(Tires, repeat=num_tires):  # Allow repeated tire usage
        if len(set(perm)) < 2:  # Ensure at least two different types of tires are used
            continue  # Skip strategies with only one type of tire
        for pit_laps in product(range(1, Number_of_Laps), repeat=num_tires - 1):  # Generate pit stop combinations
            if sum(pit_laps) < Number_of_Laps:  # Ensure total pit laps don't exceed total laps
                strategies.append((perm, list(pit_laps)))

# Simulate all strategies and find the fastest one
best_time = float("inf")
best_strategy = None
best_sc_laps = None

for strategy, pit_laps in strategies:
    total_time, sc_laps = simulate_race(strategy, pit_laps)
    if total_time < best_time:
        best_time = total_time
        best_strategy = (strategy, pit_laps)
        best_sc_laps = sc_laps  # Store SC laps for the fastest strategy

# Output the best strategy and its total time
cumulative_pit_laps = [sum(best_strategy[1][:i+1]) for i in range(len(best_strategy[1]))]  # Calculate cumulative lap numbers
print(f"Best Strategy: {best_strategy[0]} with pit stops at laps {cumulative_pit_laps}")
print(f"Total Time: {best_time:.2f} seconds")
print(f"Safety Car Active Laps: {best_sc_laps}")

# Plot the fastest strategy
simulate_race(best_strategy[0], best_strategy[1], plot=True)
# Out:
# Best Strategy: ('Medium', 'Medium', 'Hard') with pit stops at laps [16, 32]
# Total Time: 4085.60 seconds
# Safety Car Active Laps: []
# /var/folders/wk/wzjgnqcn4j77pw2772rj0nfr0000gn/T/ipykernel_10667/2307477600.py:105: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="upper left", fontsize="small", facecolor="black", edgecolor="white", labelcolor="white")
# (4085.6031236646636, [])

# %% [markdown]
# Added condition to keep SC active for 5 laps

# %%
import matplotlib.pyplot as plt
from itertools import product
import random

Number_of_Laps = 50
# Track_Length = 4.5  # km
# Track_Temp = 25  # C
# Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 97.5}  # Base pace for each tire compound
TireDegradation = {"Soft": 1.5, "Medium": 1.0, "Hard": 0.5}  # Base degradation per lap for each tire
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 1.5  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.5  # kg/lap

StopTime_Delta = 22  # s
StopTime_Delta_SC = 8  # s
StopTime_Delta_VSC = 16  # s
def Prob_SC():
    return random.random() < 0.0125

# Function to simulate a race with a given tire strategy and pit stop laps
def simulate_race(strategy, pit_laps, plot=False):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1
    CurrentTire = strategy[0]  # Start with the first tire in the strategy
    lap_times = []  # Store lap times for plotting
    lap_numbers = []  # Store lap numbers for plotting
    tire_colors = []  # Store tire colors for plotting
    laps_on_tire = 0  # Track laps completed on the current tire
    sc_laps = []  # Track laps where Prob_SC() is True
    sc_active_laps_remaining = 0  # Counter for laps remaining under safety car
    SC_Active = False  # Flag to indicate if safety car is active

    for stint_index, stint_length in enumerate(pit_laps + [Number_of_Laps - sum(pit_laps)]):
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps
            
            # Check for safety car probability or if SC is already active
            if sc_active_laps_remaining > 0:
                sc_laps.append(CurrentLap)  # Record the lap as under safety car
                sc_active_laps_remaining -= 1  # Decrease the counter
                if sc_active_laps_remaining == 0:  # Reset SC_Active when SC laps are over
                    SC_Active = False
            elif Prob_SC():
                sc_laps.append(CurrentLap)  # Record the lap where Prob_SC() is True
                sc_active_laps_remaining = 4 
                SC_Active = True # Set SC to remain active for the next 4 laps

            Fuel_Burnt = Fuel_Start - Fuel_Remaining
            # Apply exponential tire degradation
            CurrentLapTime = (
                BasePace[CurrentTire]
                + TireDegradation[CurrentTire] * (1.15 ** laps_on_tire)  # Exponential degradation
                - (Sensetivity_Weight * Fuel_Burnt) + BasePace[CurrentTire]*0.1*SC_Active
            )

            # Add pit stop time to the lap where the tire changes
            if lap == stint_length - 1 and stint_index < len(pit_laps):
                CurrentLapTime += StopTime_Delta

            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn

            # Store data for plotting
            lap_times.append(CurrentLapTime)
            lap_numbers.append(CurrentLap)
            if CurrentTire == "Soft":
                tire_colors.append("red")
            elif CurrentTire == "Medium":
                tire_colors.append("yellow")
            elif CurrentTire == "Hard":
                tire_colors.append("white")

            CurrentLap += 1
            laps_on_tire += 1  # Increment laps on the current tire

        # Switch to the next tire after the pit stop
        if stint_index < len(pit_laps):
            CurrentTire = strategy[stint_index + 1]  # Switch to the next tire
            laps_on_tire = 0  # Reset laps on the new tire

    if plot:
        # Plot the lap times with a black background
        plt.figure(figsize=(10, 6), facecolor="black")
        ax = plt.gca()
        ax.set_facecolor("black")

        # Highlight SC active phases with red bars (only if SC laps exist)
        if sc_laps:  # Check if there are any SC-active laps
            start_sc = sc_laps[0]
            for i in range(1, len(sc_laps)):
                if sc_laps[i] != sc_laps[i - 1] + 1:  # Check if the SC phase ends
                    plt.axvspan(start_sc, sc_laps[i - 1] + 1, color="red", alpha=0.3, label="SC Phase")
                    start_sc = sc_laps[i]
            # Add the last SC phase
            plt.axvspan(start_sc, sc_laps[-1] + 1, color="red", alpha=0.3, label="SC Phase")

        # Plot lap times
        for i in range(len(lap_numbers) - 1):
            plt.plot(
                lap_numbers[i:i+2],  # Plot each lap as a segment
                lap_times[i:i+2],
                color=tire_colors[i],
                linewidth=2,
            )

        plt.xlabel("Lap Number", color="white")
        plt.ylabel("Lap Time (s)", color="white")
        plt.title("Lap Time Sim (Fastest Strategy)", color="white")
        plt.grid(color="gray", linestyle="--", linewidth=0.5)
        ax.tick_params(colors="white")  # Set tick colors to white

        # Add legend only if SC phases exist
        if sc_laps:
            plt.legend(loc="upper left", fontsize="small", facecolor="black", edgecolor="white", labelcolor="white")

    plt.show()

    return CumulativeLapTime, sc_laps

# Generate all possible strategies (combinations of tires and pit stop laps)
strategies = []
for num_tires in range(2, 4):  # Allow up to 3 tire sets
    for perm in product(Tires, repeat=num_tires):  # Allow repeated tire usage
        if len(set(perm)) < 2:  # Ensure at least two different types of tires are used
            continue  # Skip strategies with only one type of tire
        for pit_laps in product(range(1, Number_of_Laps), repeat=num_tires - 1):  # Generate pit stop combinations
            if sum(pit_laps) < Number_of_Laps:  # Ensure total pit laps don't exceed total laps
                strategies.append((perm, list(pit_laps)))

# Simulate all strategies and find the fastest one
best_time = float("inf")
best_strategy = None
best_sc_laps = None

for strategy, pit_laps in strategies:
    total_time, sc_laps = simulate_race(strategy, pit_laps, plot=False)  # Ensure plot=False during strategy evaluation
    if total_time < best_time:
        best_time = total_time
        best_strategy = (strategy, pit_laps)
        best_sc_laps = sc_laps  # Store SC laps for the fastest strategy

# Output the best strategy and its total time
cumulative_pit_laps = [sum(best_strategy[1][:i+1]) for i in range(len(best_strategy[1]))]  # Calculate cumulative lap numbers
print(f"Best Strategy: {best_strategy[0]} with pit stops at laps {cumulative_pit_laps}")
print(f"Total Time: {best_time:.2f} seconds")
print(f"Safety Car Active Laps: {best_sc_laps}")

# Plot the fastest strategy
simulate_race(best_strategy[0], best_strategy[1], plot=True)  # Plot only for the fastest strategy
# Out:
# Best Strategy: ('Medium', 'Hard', 'Medium') with pit stops at laps [16, 34]
# Total Time: 4085.60 seconds
# Safety Car Active Laps: []
# (4123.803123664663, [35, 36, 37, 38, 39])

# %% [markdown]
# Use the same SC Phases for all simulation runs

# %%
import matplotlib.pyplot as plt
from itertools import product
import random

Number_of_Laps = 50
# Track_Length = 4.5  # km
# Track_Temp = 25  # C
# Track_Condition = 1.0  # 1.0 = dry, 0.8 = wet, 0.5 = very wet

# create a random number of laps where SC is active for 5 laps (sc_duration)
def generate_sc_schedule(number_of_laps, sc_probability=0.0125, sc_duration=5):
    sc_laps = []
    for lap in range(1, number_of_laps + 1):
        if random.random() < sc_probability and (not sc_laps or lap > sc_laps[-1] + sc_duration):
            sc_laps.extend(range(lap, min(lap + sc_duration, number_of_laps + 1)))
    return sc_laps

# Generate the safety car schedule for given number of laps
shared_sc_schedule = generate_sc_schedule(Number_of_Laps)
print(f"Safety Car in Laps: {shared_sc_schedule}")

#Hyperparameters
BasePace = {"Soft": 94.5, "Medium": 95.5, "Hard": 97.5}  # Base pace for each tire compound
TireDegradation = {"Soft": 1.5, "Medium": 1.25, "Hard": 1.1}  # Base degradation per lap for each tire
Tires = ["Soft", "Medium", "Hard"]

Sensetivity_Weight = 1.5  # s/kg
Fuel_Start = 45  # kg
Fuel_Burn = 0.75  # kg/lap

StopTime_Delta = 24  # s
StopTime_Delta_SC = 8  # s
StopTime_Delta_VSC = 16  # s

# Simulating the total time it takes under a given tire strategy, pit laps and safety car schedule
def simulate_race(strategy, pit_laps, sc_schedule, plot=False):
    CumulativeLapTime = 0.0
    Fuel_Remaining = Fuel_Start
    CurrentLap = 1
    CurrentTire = strategy[0]  # Start with the first tire in the strategy
    lap_times = []  # Store lap times for plotting
    lap_numbers = []  # Store lap numbers for plotting
    tire_colors = []  # Store tire colors for plotting
    laps_on_tire = 0  # Track laps completed on the current tire
    sc_laps = []  # Track laps where SC is active

    for stint_index, stint_length in enumerate(pit_laps + [Number_of_Laps - sum(pit_laps)]): 
        for lap in range(stint_length):
            if CurrentLap > Number_of_Laps:
                break  # Stop if we've completed all laps

            Fuel_Burnt = Fuel_Start - Fuel_Remaining

            # Check if the current lap is in the predefined SC schedule
            SC_Active = CurrentLap in sc_schedule
            if SC_Active:
                sc_laps.append(CurrentLap)  # Record the lap as under safety car
                CurrentLapTime = (
                    BasePace[CurrentTire]
                    + TireDegradation[CurrentTire] * (1.0 ** laps_on_tire)  # Reduce Tire Deg under SC
                    + BasePace[CurrentTire] * 0.5 * SC_Active # no fuel burnt advantage
                )
            else:
                CurrentLapTime = (
                    BasePace[CurrentTire]
                    + TireDegradation[CurrentTire] * (1.15 ** laps_on_tire)  # Exponential degradation
                    - (Sensetivity_Weight * Fuel_Burnt)
                )

            # If there is a pit stop this lap, add the pit stop time delta
            if lap == stint_length - 1 and stint_index < len(pit_laps):
                # Adjust pit stop time based on SC_Active
                if SC_Active:
                    CurrentLapTime += StopTime_Delta_SC
                else:
                    CurrentLapTime += StopTime_Delta

            CumulativeLapTime += CurrentLapTime
            Fuel_Remaining -= Fuel_Burn

            # Store data for plotting
            lap_times.append(CurrentLapTime)
            lap_numbers.append(CurrentLap)
            if CurrentTire == "Soft":
                tire_colors.append("red")
            elif CurrentTire == "Medium":
                tire_colors.append("yellow")
            elif CurrentTire == "Hard":
                tire_colors.append("white")

            CurrentLap += 1
            laps_on_tire += 1  # Increment laps on the current tire

        # Switch to the next tire after the pit stop
        if stint_index < len(pit_laps):
            CurrentTire = strategy[stint_index + 1]  # Switch to the next tire
            laps_on_tire = 0  # Reset laps on the new tire

    if plot:
        # Plot the lap times with a black background
        plt.figure(figsize=(10, 6), facecolor="black")
        ax = plt.gca()
        ax.set_facecolor("black")

        # Highlight SC active phases with red bars (only if SC laps exist)
        if sc_laps:  # Check if there are any SC-active laps
            start_sc = sc_laps[0]
            for i in range(1, len(sc_laps)):
                if sc_laps[i] != sc_laps[i - 1] + 1:  # Check if the SC phase ends
                    plt.axvspan(start_sc, sc_laps[i - 1] + 1, color="red", alpha=0.3, label="SC Phase")
                    start_sc = sc_laps[i]
            # Add the last SC phase
            plt.axvspan(start_sc, sc_laps[-1] + 1, color="red", alpha=0.3, label="SC Phase")

        # Plot lap times
        for i in range(len(lap_numbers) - 1):
            plt.plot(
                lap_numbers[i:i+2],  # Plot each lap as a segment
                lap_times[i:i+2],
                color=tire_colors[i],
                linewidth=2,
            )

        plt.xlabel("Lap Number", color="white")
        plt.ylabel("Lap Time (s)", color="white")
        plt.title("Lap Time Sim (Fastest Strategy)", color="white")
        plt.grid(color="gray", linestyle="--", linewidth=0.5)
        ax.tick_params(colors="white")  # Set tick colors to white

        # Add legend only if SC phases exist
        if sc_laps:
            plt.legend(loc="upper left", fontsize="small", facecolor="black", edgecolor="white", labelcolor="white")

    plt.show()

    return CumulativeLapTime, sc_laps

# Generate all possible strategies (combinations of tires and pit stop laps)
strategies = []
for num_tires in range(2, 4):  # Allow up to 4 tire sets
    for perm in product(Tires, repeat=num_tires):  # Allow repeated tire usage
        if len(set(perm)) < 2:  # Ensure at least two different types of tires are used
            continue  # Skip strategies with only one type of tire
        for pit_laps in product(range(1, Number_of_Laps), repeat=num_tires - 1):  # Generate pit stop combinations
            if sum(pit_laps) < Number_of_Laps:  # Ensure total pit laps don't exceed total laps
                strategies.append((perm, list(pit_laps)))

# Simulate all strategies and find the fastest one
best_time = float("inf")
best_strategy = None
best_sc_laps = None

for strategy, pit_laps in strategies:
    total_time, sc_laps = simulate_race(strategy, pit_laps, sc_schedule=shared_sc_schedule, plot=False)
    if total_time < best_time:
        best_time = total_time
        best_strategy = (strategy, pit_laps)
        best_sc_laps = sc_laps  # Store SC laps for the fastest strategy

# Output the best strategy and its total time
cumulative_pit_laps = [sum(best_strategy[1][:i+1]) for i in range(len(best_strategy[1]))]  # Calculate cumulative lap numbers
print(f"Best Strategy: {best_strategy[0]} with pit stops at laps {cumulative_pit_laps}")
print(f"Total Time: {best_time:.2f} seconds")

# Plot the fastest strategy
simulate_race(best_strategy[0], best_strategy[1], sc_schedule=shared_sc_schedule, plot=True)
# Out:
# Safety Car in Laps: [4, 5, 6, 7, 8, 32, 33, 34, 35, 36]
# Best Strategy: ('Soft', 'Soft', 'Medium') with pit stops at laps [15, 36]
# Total Time: 4284.32 seconds
# (4284.3212277723405, [4, 5, 6, 7, 8, 32, 33, 34, 35, 36])
